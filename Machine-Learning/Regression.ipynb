# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanDubeySF/random/blob/main/Machine-Learning/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
data=fetch_california_housing()
data.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
x=pd.DataFrame(data.data,columns=data.feature_names)
x.drop(['Latitude','Longitude'],axis=1,inplace=True)
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467
# ...       ...       ...       ...        ...         ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981
#
# [20640 rows x 6 columns]

# %%
y=pd.DataFrame(data.target,columns=['target'])
y
# Out:
#        target
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# 4       3.422
# ...       ...
# 20635   0.781
# 20636   0.771
# 20637   0.923
# 20638   0.847
# 20639   0.894
#
# [20640 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=69)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 2578   3.2216      34.0  6.252616   1.049327      1891.0  2.826607
# 9399   8.6340      48.0  5.615942   0.916667       641.0  2.322464
# 2674   3.3472      31.0  5.607143   1.089286       152.0  2.714286
# 15406  2.9875      13.0  5.006908   1.134715      1946.0  3.360967
# 20391  5.5402      20.0  6.561760   1.125212      1651.0  2.793570
# ...       ...       ...       ...        ...         ...       ...
# 4374   3.0958      49.0  4.034247   1.066210      1066.0  2.433790
# 11825  3.6354      17.0  5.471061   1.062701      1540.0  2.475884
# 14740  4.1518      22.0  5.663073   1.075472      1551.0  4.180593
# 9818   3.7614      52.0  5.440217   1.038043       425.0  2.309783
# 4041   7.1390      34.0  7.094000   1.046000      1187.0  2.374000
#
# [16512 rows x 6 columns]

# %% [markdown]
# ## Standardize data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(LinearRegression(),x_train,y_train,scoring='r2',cv=20)
scores
# Out:
# array([0.5340774 , 0.55226994, 0.32104558, 0.57607745, 0.53894618,
#        0.52748168, 0.51518211, 0.45617055, 0.60075118, 0.44987102,
#        0.54783809, 0.54481615, 0.56698191, 0.58419013, 0.56108742,
#        0.53464879, 0.55176742, 0.5179301 , 0.57947108, 0.53824194])

# %%
scores.mean()
# Out:
# 0.5299423064219735

# %%
from sklearn.metrics import r2_score
y_reg=reg.predict(x_test)
r2_score(y_test,y_reg)
# Out:
# 0.5386180612958285

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()

# %%
from sklearn.model_selection import GridSearchCV
param={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,50,70,80,90]}
ridgecv=GridSearchCV(ridge,param,scoring='r2',cv=5,return_train_score=True)
ridgecv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 50, 70, 80,
#                                    90]},
#              return_train_score=True, scoring='r2')

# %%
ridgecv.best_score_
# Out:
# 0.5333576357675511

# %%
y_ridge=ridgecv.predict(x_test)
r2_score(y_test,y_ridge)
# Out:
# 0.5391146549785745

# %% [markdown]
# #  Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()

# %%
param={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,50,70,80,90]}
lassocv=GridSearchCV(lasso,param,scoring='r2',cv=5,return_train_score=True)
lassocv.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.372e+02, tolerance: 1.748e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.991e+02, tolerance: 1.764e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 50, 70, 80,
#                                    90]},
# ...

# %%
lassocv.best_score_
# Out:
# 0.5331159738308295

# %%
y_lasso=lassocv.predict(x_test)
r2_score(y_test,y_lasso)
# Out:
# 0.5389015348552767

# %% [markdown]
# # ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet
elastic=ElasticNet()

# %%
elasticCV=GridSearchCV(ElasticNet(),param,scoring='r2',cv=5)
elasticCV.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.262e+01, tolerance: 1.747e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.046e+03, tolerance: 1.748e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
elasticCV.best_score_
# Out:
# 0.5335773556052488

# %%
y_elastic=elasticCV.predict(x_test)
r2_score(y_test,y_elastic)
# Out:
# 0.5390245887543523
